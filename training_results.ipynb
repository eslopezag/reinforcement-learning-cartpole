# %%
# %run cartpole_agents.py sarsa 30000
# Out:
# 100%|██████████| 30000/30000 [22:19<00:00, 22.40it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_agents\sarsa\model\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_agents\sarsa\target_model\assets

# %%
# %run cartpole_agents.py q_learning 20000
# Out:
# 100%|██████████| 20000/20000 [14:30<00:00, 22.99it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_agents\q_learning\model\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_agents\q_learning\target_model\assets

# %%
# %run cartpole_agents.py avg_reward_expected_sarsa 30000
# Out:
# 100%|██████████| 30000/30000 [22:18<00:00, 22.41it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_agents\avg_reward_expected_sarsa\model\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_agents\avg_reward_expected_sarsa\target_model\assets

# %%
# %run cartpole_agents.py discounted_expected_sarsa 30000
# Out:
# 100%|██████████| 30000/30000 [22:25<00:00, 22.30it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_agents\discounted_expected_sarsa\model\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: saved_agents\discounted_expected_sarsa\target_model\assets
